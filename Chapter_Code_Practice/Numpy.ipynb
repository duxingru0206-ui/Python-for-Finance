# %% [markdown]
# 1. data array

# %% [markdown]
# 1.1 Create an array using Python lists

# %%
v = [0.5, 0.75, 1.0, 1.5, 2.0]
m = [v, v, v]
m
# Out:
# [[0.5, 0.75, 1.0, 1.5, 2.0],
#  [0.5, 0.75, 1.0, 1.5, 2.0],
#  [0.5, 0.75, 1.0, 1.5, 2.0]]

# %%
m[1]
# Out:
# [0.5, 0.75, 1.0, 1.5, 2.0]

# %%
m[1][0]
# Out:
# 0.5

# %%
v1=[0.5,1.5]
v2=[1,2]
m=[v1,v2]
c=[m,m]
c
# Out:
# [[[0.5, 1.5], [1, 2]], [[0.5, 1.5], [1, 2]]]

# %%
v = [0.5, 0.75, 1.0, 1.5, 2.0]
m = [v, v, v]
m
# Out:
# [[0.5, 0.75, 1.0, 1.5, 2.0],
#  [0.5, 0.75, 1.0, 1.5, 2.0],
#  [0.5, 0.75, 1.0, 1.5, 2.0]]

# %%
v[0] = 'python'
m
# Out:
# [['python', 0.75, 1.0, 1.5, 2.0],
#  ['python', 0.75, 1.0, 1.5, 2.0],
#  ['python', 0.75, 1.0, 1.5, 2.0]]

# %%
from copy import deepcopy
v = [0.5, 0.75, 1.0, 1.5, 2.0]
m = 3 * [deepcopy(v)]
m
# Out:
# [[0.5, 0.75, 1.0, 1.5, 2.0],
#  [0.5, 0.75, 1.0, 1.5, 2.0],
#  [0.5, 0.75, 1.0, 1.5, 2.0]]

# %%
v[0]='python'
m
# Out:
# [[0.5, 0.75, 1.0, 1.5, 2.0],
#  [0.5, 0.75, 1.0, 1.5, 2.0],
#  [0.5, 0.75, 1.0, 1.5, 2.0]]

# %% [markdown]
# 2.2 Python array type

# %%
v = [0.5, 0.75, 1.0, 1.5, 2.0]
import array 
a = array.array('f', v)
a
# Out:
# array('f', [0.5, 0.75, 1.0, 1.5, 2.0])

# %%
a.append(0.5)
a
# Out:
# array('f', [0.5, 0.75, 1.0, 1.5, 2.0, 0.5])

# %%
a.extend([5.0,6.75])
a
# Out:
# array('f', [0.5, 0.75, 1.0, 1.5, 2.0, 0.5, 5.0, 6.75])

# %%
2*a
# Out:
# array('f', [0.5, 0.75, 1.0, 1.5, 2.0, 0.5, 5.0, 6.75, 0.5, 0.75, 1.0, 1.5, 2.0, 0.5, 5.0, 6.75])

# %%
a.append('string')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 a.append('string')
#
# TypeError: must be real number, not str

# %%
a.tolist()
# Out:
# [0.5, 0.75, 1.0, 1.5, 2.0, 0.5, 5.0, 6.75]

# %%
f = open('array.apy','wb')
a.tofile(f)
f.close()

# %%
b = array.array('f')
with open('array.apy','rb') as f:
    b.fromfile(f,5)
b
# Out:
# array('f', [0.5, 0.75, 1.0, 1.5, 2.0])

# %%
b = array.array('d')
with open('array.apy','rb') as f:
    b.fromfile(f,2)
b
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# Cell In[27], line 3
#       1 b = array.array('d')
#       2 with open('array.apy','rb') as f:
# ----> 3     b.fromfile(f,2)
#       4 b
#
# EOFError: read() didn't return enough bytes

# %% [markdown]
# 4.2 Regular numpy array

# %%
import numpy as np
