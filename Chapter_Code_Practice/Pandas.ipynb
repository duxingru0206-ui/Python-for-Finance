# %% [markdown]
# 5.1 DataFrame

# %% [markdown]
# 5.1.1 the first step to use dataframe

# %%
import pandas as pd
df = pd.DataFrame([10,20,30,40],columns=['numbers'],index=['a','b','c','d'])
df
# Out:
#    numbers
# a       10
# b       20
# c       30
# d       40

# %%
df.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='str')

# %%
df.columns
# Out:
# Index(['numbers'], dtype='str')

# %%
df.loc['c']
# Out:
# numbers    30
# Name: c, dtype: int64

# %%
df.loc[['a','d']]
# Out:
#    numbers
# a       10
# d       40

# %%
df.iloc[1:3]
# Out:
#    numbers
# b       20
# c       30

# %%
df.sum()
# Out:
# numbers    100
# dtype: int64

# %%
df.apply(lambda x: x**2)
# Out:
#    numbers
# a      100
# b      400
# c      900
# d     1600

# %%
df**2
# Out:
#    numbers
# a      100
# b      400
# c      900
# d     1600

# %%
df['float'] = (1.5,2.5,3.5,4.5)
df
# Out:
#    numbers  float
# a       10    1.5
# b       20    2.5
# c       30    3.5
# d       40    4.5

# %%
df['float']
df
# Out:
#    numbers  float
# a       10    1.5
# b       20    2.5
# c       30    3.5
# d       40    4.5

# %%
df['name'] = pd.DataFrame(['Yves','Sandra','Lilli','Henry'],index=['d','a','b','c'])
df
# Out:
#    numbers  float    name
# a       10    1.5  Sandra
# b       20    2.5   Lilli
# c       30    3.5   Henry
# d       40    4.5    Yves

# %%
df.loc['y'] = {'numbers':100,'floats':5.75,'name':'JIL'}
df
# Out:
#    numbers  float    name
# a       10    1.5  Sandra
# b       20    2.5   Lilli
# c       30    3.5   Henry
# d       40    4.5    Yves
# y      100    NaN     JIL

# %%
df.dtypes
# Out:
# numbers      int64
# float      float64
# name           str
# dtype: object

# %%
df[['numbers','float']].mean()
# Out:
# numbers    40.0
# float       3.0
# dtype: float64

# %%
df[['numbers','float']].std()
# Out:
# numbers    35.355339
# float       1.290994
# dtype: float64
