# %% [markdown]
# 6.1 Object Overview

# %% [markdown]
# 6.1.1 int

# %%
n = 5
type(n)
# Out:
# int

# %%
n.numerator
# Out:
# 5

# %%
n.bit_length()
# Out:
# 3

# %%
n + n
# Out:
# 10

# %%
2*n
# Out:
# 10

# %%
n.__sizeof__()
# Out:
# 28

# %% [markdown]
# 6.1.2 list

# %%
l = [1, 2, 3, 4]
type(l)
# Out:
# list

# %%
l[0]
# Out:
# 1

# %%
l.append(10)
l
# Out:
# [1, 2, 3, 4, 10]

# %%
l+l
# Out:
# [1, 2, 3, 4, 10, 1, 2, 3, 4, 10]

# %%
2*l
# Out:
# [1, 2, 3, 4, 10, 1, 2, 3, 4, 10]

# %%
sum(l)
# Out:
# 20

# %%
l.__sizeof__()
# Out:
# 104
